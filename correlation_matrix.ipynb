# %%
import pandas as pd
import numpy as np

features = pd.read_csv('features.csv')
features
# Out:
#                        Phone_new  Чеки  Товары   Выручка  Товар/чек  \
# 0             32565748-000000000    13      15  259458.0       1.15
# 1       32565748-535549565054 55     1       1   12430.0       1.00
# 2        32565750-575448565151 а     1       2   53198.0       2.00
# 3       32565750-575448565151 а5     1       1    1590.0       1.00
# 4       43553240-575054413251+75     7       7   48557.0       1.00
# ...                          ...   ...     ...       ...        ...
# 123107   57505548-48535350504991     1       1     999.0       1.00
# 123108   57544955-51485756555597     1       1    7700.0       1.00
# 123109   57555656-55575253555698     1       1    4040.0       1.00
# 123110   57565352-52575050555092     1       1    1999.0       1.00
# 123111   57565355-57554952485597     2       2    3879.0       1.00
#
#         Средний_чек  Чеки_выкуп  Товары_выкуп  Выручка_выкуп  Товар/чек_выкуп  \
# ...

# %%
corr = features.drop(columns='Phone_new').corr()
corr
# Out:
#                                       Чеки    Товары   Выручка  Товар/чек  \
# Чеки                              1.000000  0.453169  0.473290   0.005540
# Товары                            0.453169  1.000000  0.442324   0.863328
# Выручка                           0.473290  0.442324  1.000000   0.163425
# Товар/чек                         0.005540  0.863328  0.163425   1.000000
# Средний_чек                       0.025956  0.258435  0.697658   0.258333
# Чеки_выкуп                        0.793060  0.338710  0.322389  -0.000549
# Товары_выкуп                      0.639861  0.418244  0.353138   0.106570
# Выручка_выкуп                     0.455446  0.270710  0.601695   0.056130
# Товар/чек_выкуп                   0.050365  0.191983  0.115401   0.158196
# Средний_чек_выкуп                 0.043696  0.101747  0.424188   0.073200
# процент_выкупа                   -0.077806 -0.044355 -0.083236  -0.008140
# Мелкая бытовая техника            0.452164  0.261815  0.299545   0.023092
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(11, 11))
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
(corr > 0.7).sum()
# Out:
# Чеки                                3
# Товары                              2
# Выручка                             1
# Товар/чек                           2
# Средний_чек                         1
# Чеки_выкуп                          3
# Товары_выкуп                        2
# Выручка_выкуп                       2
# Товар/чек_выкуп                     1
# Средний_чек_выкуп                   2
# процент_выкупа                      1
# Мелкая бытовая техника              1
# Крупная бытовая техника             1
# Цифровая Техника                    1
# Сделай сам                          1
# Спорт и активный отдых              1
# Аксессуары                          1
# Детские товары                      1
# ТВ-Аудио                            1
# Мебель                              1
# Товары для дома                     1
# Климат                              1
# Игры, софт и развлечения            1
# Услуги                              1
# Автотовары                          1
# ...

# %%
corr[corr > 0.7]
# Out:
#                                       Чеки    Товары  Выручка  Товар/чек  \
# Чеки                              1.000000       NaN      NaN        NaN
# Товары                                 NaN  1.000000      NaN   0.863328
# Выручка                                NaN       NaN      1.0        NaN
# Товар/чек                              NaN  0.863328      NaN   1.000000
# Средний_чек                            NaN       NaN      NaN        NaN
# Чеки_выкуп                        0.793060       NaN      NaN        NaN
# Товары_выкуп                           NaN       NaN      NaN        NaN
# Выручка_выкуп                          NaN       NaN      NaN        NaN
# Товар/чек_выкуп                        NaN       NaN      NaN        NaN
# Средний_чек_выкуп                      NaN       NaN      NaN        NaN
# процент_выкупа                         NaN       NaN      NaN        NaN
# Мелкая бытовая техника                 NaN       NaN      NaN        NaN
# ...

# %% [markdown]
# Чеки - Чеки_выкуп
#
# Чеки - Онлайн Резерв
#
# Товары - Товар/чек
#
# Чеки_выкуп - Товары_выкуп
#
# Выручка_выкуп - Средний чек выкуп
#
#
# Онлайн резерв | Чеки выкуп | Товар / чек | Средний чек выкуп

# %%
features_dropped = features.drop(columns=['Онлайн-Резерв.', 'Чеки_выкуп', 'Товар/чек', 'Средний_чек_выкуп'])
features_dropped
# Out:
#                        Phone_new  Чеки  Товары   Выручка  Средний_чек  \
# 0             32565748-000000000    13      15  259458.0     19958.31
# 1       32565748-535549565054 55     1       1   12430.0     12430.00
# 2        32565750-575448565151 а     1       2   53198.0     53198.00
# 3       32565750-575448565151 а5     1       1    1590.0      1590.00
# 4       43553240-575054413251+75     7       7   48557.0      6936.71
# ...                          ...   ...     ...       ...          ...
# 123107   57505548-48535350504991     1       1     999.0       999.00
# 123108   57544955-51485756555597     1       1    7700.0      7700.00
# 123109   57555656-55575253555698     1       1    4040.0      4040.00
# 123110   57565352-52575050555092     1       1    1999.0      1999.00
# 123111   57565355-57554952485597     2       2    3879.0      1939.50
#
#         Товары_выкуп  Выручка_выкуп  Товар/чек_выкуп  процент_выкупа  \
# ...

# %%
features_dropped.to_csv('features_dropped.csv', index=False)
